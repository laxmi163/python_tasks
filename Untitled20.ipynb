# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmi163/python_tasks/blob/oops2/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Address:
    def __init__(self, street, city, state, zip):
        self.street = street
        self.city = city
        self.state = state
        self.zip = zip
    def str(self):
        print(self.street, self.city, self.state, self.zip)
class Employee:
    def __init__(self, name,id, address):
        self.name = name
        self.id = id
        self.address = address
    def str1(self):
        print(self.name,self.id )
        self.address.str()
address=Address("vasu nagar","darsi","ap",523247)
address1=Address("gandhi nagar","darsi","ap",523247)
employee=Employee("laxmi",548,address)
employee1=Employee("lucky",549,address1)
employee1.str1()
print("-------employee details-------")
print(employee.__dict__)
print("------adress of employee-----")
print(address.__dict__)
# Out:
# lucky 549
# gandhi nagar darsi ap 523247
# -------employee details-------
# {'name': 'laxmi', 'id': 548, 'address': <__main__.Address object at 0x791839a73a10>}
# ------adress of employee-----
# {'street': 'vasu nagar', 'city': 'darsi', 'state': 'ap', 'zip': 523247}

# %%
class Address:
  def __init__(self,street,city,state,zip):
     self.street=street
     self.city=city
     self.state=state
     self.zip=zip
  def add(self):
      print(self.street)
      print(self.city)
      print(self.state)
      print(self.zip)
class Employee:
  def __init__(self,employee_id,employee_name,address):
     self.employee_id=employee_id
     self.employee_name=employee_name
     self.address=address
  def emp(self):
      print(self.employee_id)
      print(self.employee_name)
      self.address.add()



class JuniorEngineer(Employee):
  def __init__(self,employee_id,employee_name,assessement_score,feedback,address):
     super().__init__(employee_id,employee_name,address)
     self.assessement_score = assessement_score
     self.feedback = feedback
  def display(self):
      self.emp()
      print(self.assessement_score)
      print(self.feedback)

class SoftwareEngineer(Employee):
  def __init__(self,employee_id,employee_name,project_name,address):
     super().__init__(employee_name,employee_id,address)
     self.project_name = project_name
  def show(self):
      self.emp()
      print(self.project_name)
class Trainer(Employee):
  def __init__(self,employee_name,employee_id,skills,certifications,address):
      super().__init__(employee_name,employee_id,address)
      self.skills = skills
      self.certifications = certifications
  def show1(self):
       self.emp()
       print(self.skills)
       print(self.certifications)
address= Address("vasu nagar","darsi","ap",523247)
employee=Employee(548,"laxmi",address)

junior = JuniorEngineer(101, "Lakshmi",95,"good",address)

print(junior.__dict__)
software = SoftwareEngineer(102, "Rahul", "AI Resume Builder",address)
print(software.__dict__)
trainer = Trainer(103, "Anu","Python", "AWS",address)
print(trainer.__dict__)
print("-------junioregineer------")
junior.display()
print("-----address------")
address.add()
print("-------software------")
software.show()
print("------trainer------")
trainer.show1()
# Out:
# {'employee_id': 101, 'employee_name': 'Lakshmi', 'address': <__main__.Address object at 0x791838adf3e0>, 'assessement_score': 95, 'feedback': 'good'}
# {'employee_id': 'Rahul', 'employee_name': 102, 'address': <__main__.Address object at 0x791838adf3e0>, 'project_name': 'AI Resume Builder'}
# {'employee_id': 103, 'employee_name': 'Anu', 'address': <__main__.Address object at 0x791838adf3e0>, 'skills': 'Python', 'certifications': 'AWS'}
# -------junioregineer------
# 101
# Lakshmi
# vasu nagar
# darsi
# ap
# 523247
# 95
# good
# -----address------
# vasu nagar
# darsi
# ap
# 523247
# -------software------
# Rahul
# 102
# vasu nagar
# darsi
# ap
# 523247
# AI Resume Builder
# ------trainer------
# 103
# Anu
# vasu nagar
# darsi
# ap
# 523247
# Python
# AWS
